# %%
from __future__ import absolute_import, division, print_function, unicode_literals, unicode_literals

import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 1.13.1

# %%
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

train_images.shape
len(train_labels)
train_labels
test_images.shape
len(test_labels)

plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(True)
plt.show()

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    #plt.xticks([]) : hide X axis
    #plt.yticks([]) : hide Y axis
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape = (28,28)),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10, activation = tf.nn.softmax)
])

model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
model.fit(train_images, train_labels, epochs = 5)

test_loss, test_acc = model.evaluate(test_images, test_labels)
print('test accuracy:', test_acc)

predictions = model.predict(test_images)
predictions[0]
np.argmax(predictions[0])
test_labels[0]
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 6s 100us/sample - loss: 0.5028 - acc: 0.8247
# Epoch 2/5
# 60000/60000 [==============================] - 6s 97us/sample - loss: 0.3779 - acc: 0.8635
# Epoch 3/5
# 60000/60000 [==============================] - 6s 97us/sample - loss: 0.3412 - acc: 0.8752
# Epoch 4/5
# 60000/60000 [==============================] - 6s 97us/sample - loss: 0.3138 - acc: 0.8852
# Epoch 5/5
# 60000/60000 [==============================] - 6s 96us/sample - loss: 0.2960 - acc: 0.8903
# 10000/10000 [==============================] - 1s 56us/sample - loss: 0.3475 - acc: 0.8716
# test accuracy: 0.8716
# 9

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 7700369048870736739
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 4945621811
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 2263469205021313281
# physical_device_desc: "device: 0, name: GeForce GTX 1060 6GB, pci bus id: 0000:02:00.0, compute capability: 6.1"
# ]

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('test accuracy:', test_acc)
# Out:
# 10000/10000 [==============================] - 1s 51us/sample - loss: 0.3475 - acc: 0.8716
# test accuracy: 0.8716

# %%
predictions = model.predict(test_images)

# %%
predictions[0]
# Out:
# array([1.1981263e-05, 2.8691520e-07, 2.6959384e-07, 3.4461425e-07,
#        5.5210074e-07, 3.5564220e-03, 1.4403811e-05, 1.0559043e-01,
#        6.1743990e-06, 8.9081919e-01], dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 9

# %%
len(test_images)
# Out:
# 10000

# %%
test_labels[0]
# Out:
# 9

# %%
def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img, cmap=plt.cm.binary)
    predictited_label = np.argmax(predictions_array)
    if predictited_label == true_label:
        color = 'blue'
    else:
        color = 'red'
        
    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predictited_label], 100 * np.max(predictions_array), class_names[true_label]), color = color)           
    #Example of xlabel : Ankle boot 86% (Ankle boot)

# %%
def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array[i], true_label[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color = "#777777")
    #color = "#777777" : gray color
    plt.ylim([0,1])
    predicted_label = np.argmax(predictions_array)
    
    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %%
i = 0
plt.figure(figsize = (6,3))
plt.subplot(1,2,1)
plot_image(i, predictions, test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions, test_labels)
plt.show()

# %%
i = 12
plt.figure(figsize = (6,3))
plt.subplot(1,2,1)
plot_image(i, predictions, test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions, test_labels)
plt.show()

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*num_cols, 2*num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2*num_cols, 2*i+1)
    plot_image(i, predictions, test_labels, test_images)
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i, predictions, test_labels)
plt.show()

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2*num_cols, 2*i+1)
    plot_image(i, predictions, test_labels, test_images)
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i, predictions, test_labels)
plt.show()

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*5*num_cols, 5*num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2*num_cols, 2*i+1)
    plot_image(i, predictions, test_labels, test_images)
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i, predictions, test_labels)
plt.show()

# %%
img = test_images[0]
print(img.shape)
# Out:
# (28, 28)

# %%
img = (np.expand_dims(img, 0))
print(img.shape)
# Out:
# (1, 28, 28)

# %%
predictions_single = model.predict(img)
print(predictions_single)
# Out:
# [[1.19812494e-05 2.86915707e-07 2.69594068e-07 3.44614847e-07
#   5.52101142e-07 3.55642312e-03 1.44038095e-05 1.05590478e-01
#   6.17440446e-06 8.90819073e-01]]

# %%
plot_value_array(0, predictions_single, test_labels)
plt.xticks(range(10), class_names, rotation=45)
plt.show()

# %%
prediction_result = np.argmax(predictions_single[0])
print(prediction_result)
# Out:
# 9
